# %%
import pandas as pd
import seaborn as sns
import numpy as np 
import matplotlib

data = pd.read_csv('../data/IBM_HR_ATTRITION.csv')
sns.set()
sns.distplot(data["MonthlyIncome"])

# %%
sns.distplot(data["MonthlyIncome"])
matplotlib.pyplot
